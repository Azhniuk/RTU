# %% [markdown]
# # RIGA  TECHNICAL UNIVERSITY
#
# ## FACULTY OF COMPUTER SCIENCE AND INFORMATION TECHNOLOGY
#
#
# ### Fundamentals of Computer Graphics and Image Processing
# #### Practical Work Nr. 3
# #### Name, Surname: Sofiia Azhniuk
# #### Student ID: 221ADB207
# #### Group 1

# %% [markdown]
# ## 2D transformations
# You need to translate (move), scale and rotate a 2D object, based on your variant from the variant table (available in ortus).
#
# The variant table is available in Ortus under the 5th practical lesson! Your variant is the last three digits of your student ID. For example, if your Student ID end with 154, then your variant is 154 in the variant table.
#
#
#
# Task variations:
#
# translate (move) an object by a specified amount on the x and y axis,
# scaling – increase or decrease the size of an object by a specified amount on the x and y axis
# rotate an object by a specified angle.
#
#
#
# It is obligatory to upload to Ortus a  Jupyter Notebook file (in ipynb format) with completed tasks.
#
# The Jupiter notebook file has to be formatted according to the Practical Works Template, which is available on the course page.
#
# The  Jupiter notebook file must contain:
#
# 1. Information about you (name, surname, student ID, group)
#
# 2. Description of Task of work (including your individual variant)
#
# 3. The solution of the practical work (programming code)
#
#
#
# ##Variant 207
#
# 1. 200, 200
# 2. 2, 2
# 3. 55' = 55° × π / 180°
# = 0.30555555556π rad
# = 0.9599310886 rad

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as math

img = np.ones((1000,1000,3))

# The coordinates of the points of the object
point1 = (300,100)
point2 = (100,100)
point3 = (100,300)
point4 = (300,300)


#translate
def MoveObject(move_x, move_y):
    x1 = point1[0] + move_x
    y1 = point1[1] + move_y
    x2 = point2[0] + move_x
    y2 = point2[1] + move_y
    x3 = point3[0] + move_x
    y3 = point3[1] + move_y
    x4 = point4[0] + move_x
    y4 = point4[1] + move_y
    
    xArr = [x1,x2,x3,x4,x1]
    yArr = [y1,y2,y3,y4,y1]
    plt.plot(xArr,yArr)
    return
 
    
def ScaleObject(scale_x, scale_y):
    x1 = point1[0] * scale_x
    y1 = point1[1] * scale_y
    x2 = point2[0] * scale_x
    y2 = point2[1] * scale_y
    x3 = point3[0] * scale_x
    y3 = point3[1] * scale_y
    x4 = point4[0] * scale_x
    y4 = point4[1] * scale_x
    
    xArr = [x1,x2,x3,x4,x1]
    yArr = [y1,y2,y3,y4,y1]
    plt.plot(xArr,yArr)
    return

def RotateObject(angle):
    x1 = point1[0] * math.cos(angle) - point1[1]*math.sin(angle)
    y1 = point1[0] * math.sin(angle) + point1[1]*math.cos(angle)
    
    x2 = point2[0] * math.cos(angle) - point2[1]*math.sin(angle)
    y2 = point2[0] * math.sin(angle) + point2[1]*math.cos(angle)
    
    x3 = point3[0] * math.cos(angle) - point3[1]*math.sin(angle)
    y3 = point3[0] * math.sin(angle) + point3[1]*math.cos(angle)
    
    x4 = point4[0] * math.cos(angle) - point4[1]*math.sin(angle)
    y4 = point4[0] * math.sin(angle) + point4[1]*math.cos(angle)
    
    xArr = [x1,x2,x3,x4,x1]
    yArr = [y1,y2,y3,y4,y1]
    plt.plot(xArr,yArr)
    return
    

plt.figure(figsize=(10,8), dpi = 100, facecolor='w')
plt.imshow(img)
    
MoveObject(200,200)
ScaleObject(2, 2)
RotateObject(0.9599310886)

# %% [markdown]
# ![image.png](attachment:image.png)
